# %% [markdown]
# <a href="https://colab.research.google.com/github/HyemiGu/ESC-22WINTER/blob/main/%EA%B5%AD%EB%82%B4%EC%9E%AC%EB%AC%BCLL%ED%81%B4%EB%9F%AC%EC%8A%A4%ED%84%B0%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 전처리

# %%
# Matplotlib 한글 폰트 설정
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 30 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (44.2 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121658 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
# 런타임 다시 시작 후 아래 코드 실행
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
import pandas as pd
import numpy as np

# 엑셀 파일 경로 지정
excel_file_path = '/content/(Indexed) 20240110_국내사고데이터.xlsx'

# 엑셀 파일을 데이터프레임으로 읽기
ttlclaim = pd.read_excel(excel_file_path)

# 데이터프레임 확인
display(ttlclaim)
# Out:
#                                  unique_claim_id            계약번호      UY  \
# 0          2019.07~08 Torrential Rainfall(STATS)  C2019028655442  201901
# 1          2019.07~08 Torrential Rainfall(STATS)  C2019024672398  201901
# 2          2019.07~08 Torrential Rainfall(STATS)  C2019022648225  201901
# 3          2019.07~08 Torrential Rainfall(STATS)  C2019014917987  201901
# 4          2019.07~08 Torrential Rainfall(STATS)  C2019014789929  201901
# ...                                          ...             ...     ...
# 159417                      UAE STORM (MAY 2020)  C2015020859067  201501
# 159418  Yecheon Pumped Storage Power Plant Flood  C2020012141755  202001
# 159419                             농협 BBB 수재 XOL  C2021012373226  202101
# 159420                                 폴라리스쉬핑(주)  C2019017271961  201901
# 159421                                 폴라리스쉬핑(주)  C2019017270850  201901
#
#            종목명      수재보험료       수재발생손해액   UYforIndexing       CPI  \
# 0         종합보험    69690835       2896305           2019  1.145678
# 1         종합보험    97720575       6298932           2019  1.145678
# 2         종합보험   107272821       4466931           2019  1.145678
# 3         종합보험  4933150291        783680           2019  1.145678
# 4         종합보험   122831588        151200           2019  1.145678
# ...        ...         ...           ...            ...       ...
# 159417    기술보험    99044806      12846339           2015  1.201295
# 159418    종합보험   575607015   33808436280           2020  1.139560
# 159419  기타특종보험  1199007600     845074316           2021  1.111788
# 159420    선박보험     6310437   19287917760           2019  1.145678
# 159421    선박보험    51167842  104380794705           2019  1.145678
#
#                  EPI  IncurredLoss  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0       7.984326e+07  3.318233e+06          NaN          NaN          NaN
# 1       1.119563e+08  7.216548e+06          NaN          NaN          NaN
# 2       1.229001e+08  5.117665e+06          NaN          NaN          NaN
# 3       5.651802e+09  8.978449e+05          NaN          NaN          NaN
# 4       1.407254e+08  1.732265e+05          NaN          NaN          NaN
# ...              ...           ...          ...          ...          ...
# 159417  1.189820e+08  1.543224e+07          NaN          NaN          NaN
# 159418  6.559387e+08  3.852674e+10          NaN          NaN          NaN
# 159419  1.333042e+09  9.395435e+08          NaN          NaN          NaN
# 159420  7.229729e+06  2.209774e+10          NaN          NaN          NaN
# 159421  5.862187e+07  1.195868e+11          NaN          NaN          NaN
#
#         Unnamed: 13 Korea - CPI Unnamed: 15
# 0               NaN          UY       Index
# 1               NaN        2008    1.395562
# 2               NaN        2009    1.358139
# 3               NaN        2010    1.319347
# 4               NaN        2011    1.268292
# ...             ...         ...         ...
# 159417          NaN         NaN         NaN
# 159418          NaN         NaN         NaN
# 159419          NaN         NaN         NaN
# 159420          NaN         NaN         NaN
# 159421          NaN         NaN         NaN
#
# [159422 rows x 16 columns]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
ttlclaim.info()
ttlclaim.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159422 entries, 0 to 159421
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   unique_claim_id  159422 non-null  object
#  1   계약번호             159422 non-null  object
#  2   UY               159422 non-null  int64
#  3   종목명              159422 non-null  object
#  4    수재보험료           159422 non-null  object
#  5    수재발생손해액         159422 non-null  object
#  6   UY               159422 non-null  int64
#  7   CPI              159397 non-null  float64
#  8   EPI              155848 non-null  float64
#  9   IncurredLoss     156925 non-null  float64
#  10  Unnamed: 10      0 non-null       float64
#  11  Unnamed: 11      0 non-null       float64
#  12  Unnamed: 12      0 non-null       float64
#  13  Unnamed: 13      0 non-null       float64
#  14  Korea - CPI      18 non-null      object
#  15  Unnamed: 15      18 non-null      object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 19.5+ MB
# Index(['unique_claim_id', '계약번호', 'UY', '종목명', ' 수재보험료 ', ' 수재발생손해액 ', 'UY ',
#        'CPI ', 'EPI ', 'IncurredLoss ', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Korea - CPI', 'Unnamed: 15'],
#       dtype='object')

# %%
# 수재보험료와 수재발생손해액 열을 숫자형으로 변환(문자열 " - "은 NaN으로 대체)
ttlclaim['EPI'] = pd.to_numeric(ttlclaim['EPI'], errors='coerce')
ttlclaim['IncurredLoss'] = pd.to_numeric(ttlclaim['IncurredLoss'], errors='coerce')

# %% [markdown]
# ## 국내 재물 클러스터링

# %%
ttlclaim['종목명'].unique()
# Out:
# array(['종합보험', '기술보험', '기타특종보험', '적하보험', '일반배상책임보험', '전문배상책임보험', '신종종합보험',
#        '선박보험', '상해보험', '항공보험', '보증보험', '화재보험'], dtype=object)

# %%
# 주어진 데이터프레임 (ttlclaim)에서 '종목명'이 재물보험인 보종만 선택
selected_rows = ttlclaim[ttlclaim['종목명'].isin(['종합보험', '화재보험'])]

# 새로운 데이터프레임 생성 (ProPerty)
PP = pd.DataFrame(selected_rows)

# 결과 확인
display(PP)
# Out:
#                                  unique_claim_id            계약번호      UY  \
# 0          2019.07~08 Torrential Rainfall(STATS)  C2019028655442  201901
# 1          2019.07~08 Torrential Rainfall(STATS)  C2019024672398  201901
# 2          2019.07~08 Torrential Rainfall(STATS)  C2019022648225  201901
# 3          2019.07~08 Torrential Rainfall(STATS)  C2019014917987  201901
# 4          2019.07~08 Torrential Rainfall(STATS)  C2019014789929  201901
# ...                                          ...             ...     ...
# 159374                         Typhoon TAPAH(AX)  C2018035494138  201801
# 159375                         Typhoon TAPAH(AX)  C2018035341085  201801
# 159389                         Typhoon TAPAH(AX)  C2017031323370  201701
# 159397                         Typhoon TAPAH(AX)  C2016013499698  201601
# 159418  Yecheon Pumped Storage Power Plant Flood  C2020012141755  202001
#
#          종목명      수재보험료      수재발생손해액   UYforIndexing       CPI           EPI  \
# 0       종합보험    69690835      2896305           2019  1.145678  7.984326e+07
# 1       종합보험    97720575      6298932           2019  1.145678  1.119563e+08
# 2       종합보험   107272821      4466931           2019  1.145678  1.229001e+08
# 3       종합보험  4933150291       783680           2019  1.145678  5.651802e+09
# 4       종합보험   122831588       151200           2019  1.145678  1.407254e+08
# ...      ...         ...          ...            ...       ...           ...
# 159374  종합보험   219586477      5184135           2018  1.150072  2.525403e+08
# 159375  종합보험    31978913     11866356           2018  1.150072  3.677805e+07
# 159389  종합보험   262127467     13814533           2017  1.167044  3.059143e+08
# 159397  종합보험  4940519429       475000           2016  1.189731  5.877889e+09
# 159418  종합보험   575607015  33808436280           2020  1.139560  6.559387e+08
#
#         IncurredLoss  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0       3.318233e+06          NaN          NaN          NaN          NaN
# 1       7.216548e+06          NaN          NaN          NaN          NaN
# 2       5.117665e+06          NaN          NaN          NaN          NaN
# 3       8.978449e+05          NaN          NaN          NaN          NaN
# 4       1.732265e+05          NaN          NaN          NaN          NaN
# ...              ...          ...          ...          ...          ...
# 159374  5.962129e+06          NaN          NaN          NaN          NaN
# 159375  1.364716e+07          NaN          NaN          NaN          NaN
# 159389  1.612217e+07          NaN          NaN          NaN          NaN
# 159397  5.651222e+05          NaN          NaN          NaN          NaN
# 159418  3.852674e+10          NaN          NaN          NaN          NaN
#
#        Korea - CPI Unnamed: 15
# 0               UY       Index
# 1             2008    1.395562
# 2             2009    1.358139
# 3             2010    1.319347
# 4             2011    1.268292
# ...            ...         ...
# 159374         NaN         NaN
# 159375         NaN         NaN
# 159389         NaN         NaN
# 159397         NaN         NaN
# 159418         NaN         NaN
#
# [8413 rows x 16 columns]

# %%
# claim 횟수 계산 및 데이터 정리
PP['claim횟수'] = PP.groupby(['unique_claim_id', '계약번호']).cumcount() + 1
PP['수재보험료누적'] = PP.groupby(['unique_claim_id', '계약번호'])['EPI'].cumsum()
PP['수재발생손해액누적'] = PP.groupby(['unique_claim_id', '계약번호'])['IncurredLoss'].cumsum()

# '수재발생손해액누적' / '수재보험료누적'를 계산하여 '수재손해율' 열 추가
PP['수재손해율'] = PP['수재발생손해액누적'] / PP['수재보험료누적']

# 사고빈도 1로 초기화
PP['claim횟수'] = 1

# 중복된 데이터 삭제
PP_for_analysis = PP.drop_duplicates(subset=['unique_claim_id', '계약번호'], keep='last')

# 필요한 열만 선택
PP_for_analysis = PP_for_analysis[['unique_claim_id', '계약번호', 'UY', '종목명', '수재보험료누적', '수재발생손해액누적', '수재손해율', 'claim횟수']]

display(PP_for_analysis)
# Out:
#                                  unique_claim_id            계약번호      UY  \
# 0          2019.07~08 Torrential Rainfall(STATS)  C2019028655442  201901
# 1          2019.07~08 Torrential Rainfall(STATS)  C2019024672398  201901
# 2          2019.07~08 Torrential Rainfall(STATS)  C2019022648225  201901
# 3          2019.07~08 Torrential Rainfall(STATS)  C2019014917987  201901
# 4          2019.07~08 Torrential Rainfall(STATS)  C2019014789929  201901
# ...                                          ...             ...     ...
# 159374                         Typhoon TAPAH(AX)  C2018035494138  201801
# 159375                         Typhoon TAPAH(AX)  C2018035341085  201801
# 159389                         Typhoon TAPAH(AX)  C2017031323370  201701
# 159397                         Typhoon TAPAH(AX)  C2016013499698  201601
# 159418  Yecheon Pumped Storage Power Plant Flood  C2020012141755  202001
#
#          종목명       수재보험료누적     수재발생손해액누적      수재손해율  claim횟수
# 0       종합보험  7.984326e+07  3.318233e+06   0.041559        1
# 1       종합보험  1.119563e+08  7.216548e+06   0.064459        1
# 2       종합보험  1.229001e+08  5.117665e+06   0.041641        1
# 3       종합보험  5.651802e+09  8.978449e+05   0.000159        1
# 4       종합보험  1.407254e+08  1.732265e+05   0.001231        1
# ...      ...           ...           ...        ...      ...
# 159374  종합보험  2.525403e+08  5.962129e+06   0.023609        1
# 159375  종합보험  3.677805e+07  1.364716e+07   0.371068        1
# 159389  종합보험  3.059143e+08  1.612217e+07   0.052702        1
# 159397  종합보험  5.877889e+09  5.651222e+05   0.000096        1
# 159418  종합보험  6.559387e+08  3.852674e+10  58.735275        1
#
# [8253 rows x 8 columns]

# %%
PP_for_analysis['claim횟수'].max()
# Out:
# 1

# %% [markdown]
# ## 결측치 및 음수 처리

# %%
PP_for_analysis['수재발생손해액누적'].isna().value_counts()
# Out:
# False    8130
# True      123
# Name: 수재발생손해액누적, dtype: int64

# %%
PP_for_analysis['수재보험료누적'].isna().value_counts()
# Out:
# False    8059
# True      194
# Name: 수재보험료누적, dtype: int64

# %%
PP_for_analysis.describe()
# Out:
#                   UY       수재보험료누적     수재발생손해액누적         수재손해율  claim횟수
# count    8253.000000  8.059000e+03  8.130000e+03  8.014000e+03   8253.0
# mean   201987.146977  6.484596e+09  2.733690e+08 -7.875485e+02      1.0
# std       180.199878  2.954052e+10  4.490491e+09  4.392353e+04      0.0
# min    200504.000000 -1.648164e+07 -3.589781e+09 -3.562009e+06      1.0
# 25%    201901.000000  5.254671e+07  2.034115e+05  8.412988e-04      1.0
# 50%    202001.000000  1.837699e+08  9.855353e+05  5.765481e-03      1.0
# 75%    202101.000000  1.007038e+09  8.337104e+06  5.335151e-02      1.0
# max    202301.000000  2.678771e+11  2.478595e+11  5.977083e+04      1.0

# %%
# NaN 값이 있는 행 제외
df = PP_for_analysis.dropna(subset=['수재발생손해액누적', '수재보험료누적', '수재손해율'])

# 음수 값이 있는 행 제외
df = df[(df['수재발생손해액누적'] >= 0) & (df['수재보험료누적'] >= 0) & (df['수재손해율'] >= 0)]

# %%
df.isna().value_counts()
# Out:
# unique_claim_id  계약번호   UY     종목명    수재보험료누적  수재발생손해액누적  수재손해율  claim횟수
# False            False  False  False  False    False      False  False      7810
# dtype: int64

# %%
8253-7810 # 개의 데이터 제외
# Out:
# 443

# %%
df.describe()
# Out:
#                   UY       수재보험료누적     수재발생손해액누적         수재손해율  claim횟수
# count    7810.000000  7.810000e+03  7.810000e+03  7.810000e+03   7810.0
# mean   201994.862484  6.050490e+09  2.857770e+08  8.818486e+00      1.0
# std       160.482530  2.876081e+10  4.580890e+09  6.766374e+02      0.0
# min    200804.000000  5.336582e+01  1.022981e+00  1.801559e-10      1.0
# 25%    201901.000000  4.891459e+07  2.201755e+05  1.005526e-03      1.0
# 50%    202001.000000  1.641396e+08  1.089487e+06  6.259850e-03      1.0
# 75%    202101.000000  8.316697e+08  9.237710e+06  5.830354e-02      1.0
# max    202301.000000  2.678771e+11  2.478595e+11  5.977083e+04      1.0

# %% [markdown]
# ## Outlier 제외

# %%
# 보험료와 손해액 outliers 필터링 based on z-score
z_score_threshold = 3
outlier_mask1 = (df['수재발생손해액누적'] - df['수재발생손해액누적'].mean()) / df['수재발생손해액누적'].std() > z_score_threshold
df_no_outliers1 = df[~outlier_mask1]

outlier_mask2 = (df['수재보험료누적'] - df['수재보험료누적'].mean()) / df['수재보험료누적'].std() > z_score_threshold
df_no_outliers = df_no_outliers1[~outlier_mask2]
# Out:
# <ipython-input-15-f1a7ebcc88af>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_no_outliers = df_no_outliers1[~outlier_mask2]

# %%
df_no_outliers1.describe()

# 발생손해액 아웃라이어는 총 7810 - 7779 = 31개
# Out:
#                   UY       수재보험료누적     수재발생손해액누적         수재손해율  claim횟수
# count    7779.000000  7.779000e+03  7.779000e+03  7.779000e+03   7779.0
# mean   201994.683764  5.755309e+09  8.977452e+07  8.810007e+00      1.0
# std       160.483430  2.784128e+10  5.321616e+08  6.779833e+02      0.0
# min    200804.000000  5.336582e+01  1.022981e+00  1.801559e-10      1.0
# 25%    201901.000000  4.863832e+07  2.193177e+05  9.909979e-04      1.0
# 50%    202001.000000  1.591308e+08  1.076806e+06  6.176785e-03      1.0
# 75%    202101.000000  8.316697e+08  8.800134e+06  5.592010e-02      1.0
# max    202301.000000  2.678771e+11  1.367332e+10  5.977083e+04      1.0

# %%
df_no_outliers.describe()

# 보험료까지 포함하면 아웃라이어 총 230 (=31+199) 개 제외
# Out:
#                   UY       수재보험료누적     수재발생손해액누적         수재손해율  claim횟수
# count    7580.000000  7.580000e+03  7.580000e+03  7.580000e+03   7580.0
# mean   201996.628760  1.617676e+09  7.395080e+07  9.041178e+00      1.0
# std       159.746204  4.973858e+09  4.720434e+08  6.868249e+02      0.0
# min    200804.000000  5.336582e+01  1.022981e+00  1.801559e-10      1.0
# 25%    201901.000000  4.695296e+07  2.148211e+05  1.091112e-03      1.0
# 50%    202001.000000  1.408340e+08  1.025745e+06  6.590145e-03      1.0
# 75%    202101.000000  7.357220e+08  7.749889e+06  6.001172e-02      1.0
# max    202301.000000  8.618569e+10  1.367332e+10  5.977083e+04      1.0

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Elbow Method (EPI 구간의 개수 설정)

# %%
# 아웃라이어 제거한 df 에서 보험료 열만 사용
EPI = df_no_outliers[['수재보험료누적']]

# EPI 표준화
scaler_EPI = StandardScaler()
standardized_EPI = scaler_EPI.fit_transform(EPI)

# Elbow Method 사용하여 적절한 클러스터 개수 찾기
sse_EPI =[]
K_range = range(1,11)
for K_EPI in K_range:
  kmeans_EPI = KMeans(n_clusters=K_EPI, random_state=42)
  kmeans_EPI.fit(standardized_EPI)
  sse_EPI.append(kmeans_EPI.inertia_)

# Elbow Method 그래프 출력
plt.plot(K_range, sse_EPI, marker='o')
plt.xlabel('클러스터 개수')
plt.ylabel('SSE (Sum of Squared Errors)')
plt.title('Elbow Method (EPI 구간 개수)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# #### EPI 구간이 3개일 때 k-means

# %%
from sklearn.preprocessing import StandardScaler

# StandardScaler 초기화
scaler = StandardScaler()

# 데이터를 표준화
standardized_EPI = scaler.fit_transform(EPI)

# K-means 클러스터링 (k=3)
kmeans_EPI_3 = KMeans(n_clusters=3, random_state=42)
clusters_EPI_3 = kmeans_EPI_3.fit_predict(standardized_EPI)

# 결과를 데이터프레임에 추가
df_no_outliers['클러스터_3개'] = clusters_EPI_3

# 클러스터 중심을 원래의 스케일로 변환
cluster_centers_original_scale = scaler.inverse_transform(kmeans_EPI_3.cluster_centers_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-18-9e28f9ee2d6c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_outliers['클러스터_3개'] = clusters_EPI_3

# %%
df_no_outliers
# Out:
#                               unique_claim_id            계약번호      UY   종목명  \
# 0       2019.07~08 Torrential Rainfall(STATS)  C2019028655442  201901  종합보험
# 1       2019.07~08 Torrential Rainfall(STATS)  C2019024672398  201901  종합보험
# 2       2019.07~08 Torrential Rainfall(STATS)  C2019022648225  201901  종합보험
# 3       2019.07~08 Torrential Rainfall(STATS)  C2019014917987  201901  종합보험
# 4       2019.07~08 Torrential Rainfall(STATS)  C2019014789929  201901  종합보험
# ...                                       ...             ...     ...   ...
# 159373                      Typhoon TAPAH(AX)  C2018035877898  201801  종합보험
# 159374                      Typhoon TAPAH(AX)  C2018035494138  201801  종합보험
# 159375                      Typhoon TAPAH(AX)  C2018035341085  201801  종합보험
# 159389                      Typhoon TAPAH(AX)  C2017031323370  201701  종합보험
# 159397                      Typhoon TAPAH(AX)  C2016013499698  201601  종합보험
#
#              수재보험료누적     수재발생손해액누적     수재손해율  claim횟수  클러스터_3개
# 0       7.984326e+07  3.318233e+06  0.041559        1        0
# 1       1.119563e+08  7.216548e+06  0.064459        1        0
# 2       1.229001e+08  5.117665e+06  0.041641        1        0
# 3       5.651802e+09  8.978449e+05  0.000159        1        2
# 4       1.407254e+08  1.732265e+05  0.001231        1        0
# ...              ...           ...       ...      ...      ...
# 159373  5.648448e+07  8.337113e+05  0.014760        1        0
# 159374  2.525403e+08  5.962129e+06  0.023609        1        0
# 159375  3.677805e+07  1.364716e+07  0.371068        1        0
# 159389  3.059143e+08  1.612217e+07  0.052702        1        0
# 159397  5.877889e+09  5.651222e+05  0.000096        1        2
#
# [7580 rows x 9 columns]

# %%
colors_3개 = ['paleturquoise', 'lightpink', 'wheat']
for cluster_num_EPI in range(3):
    cluster_data_EPI = EPI[clusters_EPI_3 == cluster_num_EPI]
    plt.scatter(cluster_data_EPI['수재보험료누적'],
                [cluster_num_EPI] * len(cluster_data_EPI),
                label=f'클러스터 {cluster_num_EPI}', s=50, color=colors_3개[cluster_num_EPI])

# 클러스터 중심 플로팅
plt.scatter( cluster_centers_original_scale[:, 0], [0, 1, 2], # y 값을 클러스터 인덱스로 지정
            color='slategrey', marker='X', s=200, label='클러스터 중심')

# 축 레이블 및 그래픽 설정
plt.xlabel('수재보험료(단위:백억)')
plt.ylabel('클러스터 인덱스')
plt.title('3개 군집에 대한 K-means 클러스터링 결과 (EPI 구간 개수)')
plt.legend()
plt.show()

# %%
# 클러스터 0에 해당하는 수재보험료 데이터의 최솟값
cluster_0_data_EPI = EPI[clusters_EPI_3 == 0]  # 클러스터 1에 해당하는 데이터 선택
min_value_cluster_0 = cluster_0_data_EPI['수재보험료누적'].min()  # 선택된 데이터에서 '수재보험료누적' 열의 최솟값 계산
print(f'클러스터 1에 해당하는 수재보험료 데이터의 최솟값: {min_value_cluster_0}')

# 클러스터 2에 해당하는 수재보험료 데이터의 최솟값
cluster_2_data_EPI = EPI[clusters_EPI_3 == 2]  # 클러스터 2에 해당하는 데이터 선택
min_value_cluster_2 = cluster_2_data_EPI['수재보험료누적'].min()  # 선택된 데이터에서 '수재보험료누적' 열의 최솟값 계산
print(f'클러스터 2에 해당하는 수재보험료 데이터의 최솟값: {min_value_cluster_2}')

# 클러스터 2에 해당하는 수재보험료 데이터의 최솟값
cluster_2_data_EPI = EPI[clusters_EPI_3 == 2]  # 클러스터 2에 해당하는 데이터 선택
max_value_cluster_2 = cluster_2_data_EPI['수재보험료누적'].max()  # 선택된 데이터에서 '수재보험료누적' 열의 최댓값 계산
print(f'클러스터 2에 해당하는 수재보험료 데이터의 최댓값: {max_value_cluster_2}')

# 클러스터 1에 해당하는 수재보험료 데이터의 최솟값
cluster_1_data_EPI = EPI[clusters_EPI_3 == 1]  # 클러스터 1에 해당하는 데이터 선택
min_value_cluster_1 = cluster_1_data_EPI['수재보험료누적'].min()  # 선택된 데이터에서 '수재보험료누적' 열의 최솟값 계산
print(f'클러스터 1에 해당하는 수재보험료 데이터의 최솟값: {min_value_cluster_1}')
# Out:
# 클러스터 1에 해당하는 수재보험료 데이터의 최솟값: 53.365824
# 클러스터 2에 해당하는 수재보험료 데이터의 최솟값: 3834040822.5968
# 클러스터 2에 해당하는 수재보험료 데이터의 최댓값: 17778677358.8432
# 클러스터 1에 해당하는 수재보험료 데이터의 최솟값: 19680568088.138

# %% [markdown]
# *   cluster 0 가 EPI low
# *   cluster 1 가 EPI high
# *   cluster 2 가 EPI middle

# %%
# 클러스터 0에 해당하는 데이터의 개수
count_cluster_0 = len(EPI[clusters_EPI_3 == 0])
print(f'클러스터 0에 해당하는 데이터의 개수: {count_cluster_0}')

# 클러스터 1에 해당하는 데이터의 개수
count_cluster_1 = len(EPI[clusters_EPI_3 == 1])
print(f'클러스터 1에 해당하는 데이터의 개수: {count_cluster_1}')

# 클러스터 2에 해당하는 데이터의 개수
count_cluster_2 = len(EPI[clusters_EPI_3 == 2])
print(f'클러스터 2에 해당하는 데이터의 개수: {count_cluster_2}')
# Out:
# 클러스터 0에 해당하는 데이터의 개수: 6705
# 클러스터 1에 해당하는 데이터의 개수: 169
# 클러스터 2에 해당하는 데이터의 개수: 706

# %%
# 클러스터에 따라 데이터 분류
EPI_low = df_no_outliers[df_no_outliers['클러스터_3개'] == 0]
EPI_middle = df_no_outliers[df_no_outliers['클러스터_3개'] == 2]
EPI_high = df_no_outliers[df_no_outliers['클러스터_3개'] == 1]


# 저장된 데이터프레임 확인
print("EPI_low:")
display(EPI_low.head())

print("\nEPI_middle:")
display(EPI_middle.head())

print("\nEPI_high:")
display(EPI_high.head())
# Out:
# EPI_low:
#                          unique_claim_id            계약번호      UY   종목명  \
# 0  2019.07~08 Torrential Rainfall(STATS)  C2019028655442  201901  종합보험
# 1  2019.07~08 Torrential Rainfall(STATS)  C2019024672398  201901  종합보험
# 2  2019.07~08 Torrential Rainfall(STATS)  C2019022648225  201901  종합보험
# 4  2019.07~08 Torrential Rainfall(STATS)  C2019014789929  201901  종합보험
# 5  2019.07~08 Torrential Rainfall(STATS)  C2019012890060  201901  종합보험
#
#         수재보험료누적     수재발생손해액누적     수재손해율  claim횟수  클러스터_3개
# 0  7.984326e+07  3.318233e+06  0.041559        1        0
# 1  1.119563e+08  7.216548e+06  0.064459        1        0
# 2  1.229001e+08  5.117665e+06  0.041641        1        0
# 4  1.407254e+08  1.732265e+05  0.001231        1        0
# 5  6.631874e+06  4.543915e+06  0.685163        1        0
# EPI_middle:
#                            unique_claim_id            계약번호      UY   종목명  \
# 3    2019.07~08 Torrential Rainfall(STATS)  C2019014917987  201901  종합보험
# 104             202007~08 Monsoon Rainfall  C2020022742871  202001  종합보험
# 163             202007~08 Monsoon Rainfall  C2020018670035  202001  종합보험
# 194             202007~08 Monsoon Rainfall  C2020013994976  202001  종합보험
# 217             202007~08 Monsoon Rainfall  C2019040900175  201901  종합보험
#
#           수재보험료누적     수재발생손해액누적     수재손해율  claim횟수  클러스터_3개
# 3    5.651802e+09  8.978449e+05  0.000159        1        2
# 104  6.425057e+09  7.777259e+07  0.012105        1        2
# 163  6.318876e+09  9.392992e+07  0.014865        1        2
# 194  4.632860e+09  1.423880e+05  0.000031        1        2
# 217  1.039686e+10  1.698379e+08  0.016335        1        2
# EPI_high:
#                         unique_claim_id            계약번호      UY   종목명  \
# 189          202007~08 Monsoon Rainfall  C2020014169766  202001  종합보험
# 515   2023 Monsoon Rainfall (6.25-7.26)  C2023012397224  202301  종합보험
# 6254            C2017023582892-20190120  C2017023582892  201701  종합보험
# 6255            C2017023582892-20190220  C2017023582892  201701  종합보험
# 6256            C2017023582892-20190520  C2017023582892  201701  종합보험
#
#            수재보험료누적     수재발생손해액누적     수재손해율  claim횟수  클러스터_3개
# 189   8.618569e+10  3.975118e+09  0.046123        1        1
# 515   5.030799e+10  8.099036e+08  0.016099        1        1
# 6254  4.209203e+10  1.887283e+08  0.004484        1        1
# 6255  4.209203e+10  5.237871e+07  0.001244        1        1
# 6256  4.209203e+10  5.879574e+07  0.001397        1        1

# %% [markdown]
# ### EPI 구간 별 클러스터링

# %% [markdown]
# #### Elbow Method (epi low)

# %%
# EPI low 에서 '수재보험료누적', '수재발생손해액누적' 열만 사용
df_EPI_low = EPI_low[['수재보험료누적', '수재발생손해액누적']]

# 데이터 표준화
scaler_EPI_low = StandardScaler()
standardized_EPI_low = scaler_EPI_low.fit_transform(df_EPI_low)

# Elbow Method를 사용하여 적절한 클러스터 개수 찾기
sse_EPI_low = []
K_EPI_low = range(1, 11)
for k_low in K_EPI_low:
    kmeans_EPI_low = KMeans(n_clusters=k_low, random_state=42)
    kmeans_EPI_low.fit(standardized_EPI_low)
    sse_EPI_low.append(kmeans_EPI_low.inertia_)

# Elbow Method 그래프 출력
plt.plot(K_EPI_low, sse_EPI_low, color = 'lightseagreen', marker='o')
plt.xlabel('클러스터 개수')
plt.ylabel('SSE (Sum of Squared Errors)')
plt.title('Elbow Method (EPI low)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# #### k = 5 일 때 k-means

# %%
# K-means 클러스터링 (k=5)
kmeans_EPI_low_5 = KMeans(n_clusters=5, random_state=42)
clusters_EPI_low_5 = kmeans_EPI_low_5.fit_predict(standardized_EPI_low)

# 결과를 데이터프레임에 추가
EPI_low['5-Means'] = clusters_EPI_low_5
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-23-1b2861694946>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EPI_low['5-Means'] = clusters_EPI_low_5

# %%
# 각 클러스터에 대해 데이터 포인트를 2차원 평면에 플로팅
colors_EPI_low_5 = ['paleturquoise', 'bisque', 'lightcoral', 'thistle', 'palegreen']
for cluster_num_EPI_low_5 in range(5):
    cluster_data_EPI_low_5 = EPI_low[clusters_EPI_low_5 == cluster_num_EPI_low_5]
    plt.scatter(cluster_data_EPI_low_5['수재보험료누적'], cluster_data_EPI_low_5['수재발생손해액누적'],
                label=f'클러스터 {cluster_num_EPI_low_5}', s=50, color=colors_EPI_low_5[cluster_num_EPI_low_5])

# 클러스터 중심 플로팅
cluster_centers_2d_EPI_low_5 = scaler_EPI_low.inverse_transform(kmeans_EPI_low_5.cluster_centers_)
plt.scatter(cluster_centers_2d_EPI_low_5[:, 0], cluster_centers_2d_EPI_low_5[:, 1],
            color='slategrey', marker='X', s=200, label='클러스터 중심')

# 축 레이블 및 그래픽 설정
plt.axhline(y=1018944642, color='red', linestyle='--', label='Threshold')
plt.xlabel('수재보험료(단위:십억원)')
plt.ylabel('수재발생손해액(단위:십억원)')
plt.title('5개 군집에 대한 K-means 클러스터링 결과 (EPI low)')
plt.legend()
plt.show()

# %%
# 5개 클러스터에 해당하는 데이터의 개수 알아내기
count_clusters_EPI_low_k5 = []
for cluster_num in range(5):
    count = len(EPI_low[clusters_EPI_low_5 == cluster_num])
    count_clusters_EPI_low_k5.append(count)
    print(f'클러스터 {cluster_num}에 해당하는 데이터의 개수: {count}')
# Out:
# 클러스터 0에 해당하는 데이터의 개수: 5312
# 클러스터 1에 해당하는 데이터의 개수: 427
# 클러스터 2에 해당하는 데이터의 개수: 54
# 클러스터 3에 해당하는 데이터의 개수: 898
# 클러스터 4에 해당하는 데이터의 개수: 14

# %%
# 원하는 열 선택
선택된_열 = ['수재보험료누적', '수재발생손해액누적']

# 각 클러스터 중심값 출력 (부동소수점 표기법 수정)
클러스터별_중심값 = pd.DataFrame(scaler_EPI_low.inverse_transform(kmeans_EPI_low_5.cluster_centers_), columns=선택된_열)
# 부동소수점 표기법 수정 및 출력
pd.set_option('display.float_format', lambda x: '{:,.0f}'.format(x))
print("\n각 클러스터 중심값:")
display(클러스터별_중심값)
# Out:
# 각 클러스터 중심값:
#         수재보험료누적     수재발생손해액누적
# 0   125,953,038    16,462,100
# 1 2,189,581,214    37,264,725
# 2   894,669,130 1,890,592,186
# 3   876,152,953    28,677,238
# 4   610,121,899 5,721,617,618

# %%
# 클러스터 2에 해당하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터 찾기
cluster_2_data_min_loss_EPI_low = EPI_low[EPI_low['5-Means'] == 2].nsmallest(1, '수재발생손해액누적')

# 부동소수점 표기법 수정 및 'e' 제거
cluster_2_data_min_loss_EPI_low['수재발생손해액누적'] = cluster_2_data_min_loss_EPI_low['수재발생손해액누적'].apply(lambda x: '{:,.0f}'.format(x))
cluster_2_data_min_loss_EPI_low['수재보험료누적'] = cluster_2_data_min_loss_EPI_low['수재보험료누적'].apply(lambda x: '{:,.0f}'.format(x))

# 출력
print("\n클러스터 2에 속하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터:")
display(cluster_2_data_min_loss_EPI_low)
# Out:
# 클러스터 2에 속하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터:
#                 unique_claim_id            계약번호      UY   종목명      수재보험료누적  \
# 120226  C2021029607662-20220317  C2021029607662  202101  종합보험  284,781,397
#
#             수재발생손해액누적  수재손해율  claim횟수  클러스터_3개  5-Means
# 120226  1,018,944,642      4        1        0        2

# %% [markdown]
# ✅ 10억 1,894만 원

# %% [markdown]
# #### Elbow Method (epi middle)

# %%
# EPI_middle에서 '수재보험료누적', '수재발생손해액누적' 열만 선택
df_EPI_middle = EPI_middle[['수재보험료누적', '수재발생손해액누적']]

# 데이터 표준화
scaler_EPI_middle = StandardScaler()
standardized_EPI_middle = scaler_EPI_middle.fit_transform(df_EPI_middle)

# Elbow Method를 사용하여 적절한 클러스터 개수 찾기
sse_EPI_middle = []
K_EPI_middle = range(1, 11)
for k_middle in K_EPI_middle:
    kmeans_EPI_middle = KMeans(n_clusters=k_middle, random_state=42)
    kmeans_EPI_middle.fit(standardized_EPI_middle)
    sse_EPI_middle.append(kmeans_EPI_middle.inertia_)

# Elbow Method 그래프 출력
plt.plot(K_EPI_middle, sse_EPI_middle, color='lightseagreen', marker='o')
plt.xlabel('클러스터 개수')
plt.ylabel('SSE (Sum of Squared Errors)')
plt.title('Elbow Method (EPI middle)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# #### k = 5 일 때 k-means

# %%
# K-means 클러스터링 (k=5) - EPI_middle 기준
kmeans_EPI_middle_k5 = KMeans(n_clusters=5, random_state=42)
clusters_EPI_middle_k5 = kmeans_EPI_middle_k5.fit_predict(standardized_EPI_middle)

# 결과를 데이터프레임에 추가
EPI_middle['5-Means'] = clusters_EPI_middle_k5

# 클러스터링 결과 시각화
colors_EPI_middle_5 = ['paleturquoise', 'lightcoral', 'bisque', 'thistle', 'palegreen']
for cluster_num_EPI in range(5):
    cluster_data_EPI = EPI_middle[clusters_EPI_middle_k5 == cluster_num_EPI]
    plt.scatter(cluster_data_EPI['수재보험료누적'],
                cluster_data_EPI['수재발생손해액누적'],
                label=f'클러스터 {cluster_num_EPI}', s=50, color=colors_EPI_middle_5[cluster_num_EPI])

# 클러스터 중심 플로팅
cluster_centers_2d_EPI_middle_k5 = scaler_EPI_middle.inverse_transform(kmeans_EPI_middle_k5.cluster_centers_)
plt.scatter(cluster_centers_2d_EPI_middle_k5[:, 0], cluster_centers_2d_EPI_middle_k5[:, 1],
            color='slategrey', marker='X', s=200, label='클러스터 중심')

# 축 레이블 및 그래픽 설정
plt.axhline(y=1321919850, color='red', linestyle='--', label='Threshold')
plt.xlabel('수재보험료누적(단위:백억원)')
plt.ylabel('수재발생손해액누적(단위:백억원)')
plt.title('5개 군집에 대한 K-means 클러스터링 결과 (EPI middle)')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-26-767fff07a12b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EPI_middle['5-Means'] = clusters_EPI_middle_k5

# %%
# 5개 클러스터에 해당하는 데이터의 개수 알아내기
count_clusters_EPI_middle_k5 = []
for cluster_num in range(5):
    count = len(EPI_middle[clusters_EPI_middle_k5 == cluster_num])
    count_clusters_EPI_middle_k5.append(count)
    print(f'클러스터 {cluster_num}에 해당하는 데이터의 개수: {count}')
# Out:
# 클러스터 0에 해당하는 데이터의 개수: 552
# 클러스터 1에 해당하는 데이터의 개수: 31
# 클러스터 2에 해당하는 데이터의 개수: 4
# 클러스터 3에 해당하는 데이터의 개수: 21
# 클러스터 4에 해당하는 데이터의 개수: 98

# %%
# 클러스터 3에 해당하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터 찾기
cluster_3_data_min_loss_EPI_middle = EPI_middle[EPI_middle['5-Means'] == 3].nsmallest(1, '수재발생손해액누적')

# 부동소수점 표기법 수정 및 'e' 제거
cluster_3_data_min_loss_EPI_middle['수재발생손해액누적'] = cluster_3_data_min_loss_EPI_middle['수재발생손해액누적'].apply(lambda x: '{:,.0f}'.format(x))
cluster_3_data_min_loss_EPI_middle['수재보험료누적'] = cluster_3_data_min_loss_EPI_middle['수재보험료누적'].apply(lambda x: '{:,.0f}'.format(x))

# 출력
print("\n클러스터 3에 속하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터:")
display(cluster_3_data_min_loss_EPI_middle)
# Out:
# 클러스터 3에 속하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터:
#                unique_claim_id            계약번호      UY   종목명        수재보험료누적  \
# 52890  C2020014169766-20200918  C2020014169766  202001  종합보험  5,069,746,226
#
#            수재발생손해액누적  수재손해율  claim횟수  클러스터_3개  5-Means
# 52890  1,321,919,850      0        1        2        3

# %%
# 클러스터 1에 해당하는 데이터 중에서 가장 큰 수재발생손해액누적값을 가진 데이터 찾기
cluster_1_data_max_loss_EPI_middle = EPI_middle[EPI_middle['5-Means'] == 1].nlargest(1, '수재발생손해액누적')

# 부동소수점 표기법 수정 및 'e' 제거
cluster_1_data_max_loss_EPI_middle['수재발생손해액누적'] = cluster_1_data_max_loss_EPI_middle['수재발생손해액누적'].apply(lambda x: '{:,.0f}'.format(x))
cluster_1_data_max_loss_EPI_middle['수재보험료누적'] = cluster_1_data_max_loss_EPI_middle['수재보험료누적'].apply(lambda x: '{:,.0f}'.format(x))

# 출력
print("\n클러스터 1에 속하는 데이터 중에서 가장 큰 수재발생손해액누적값을 가진 데이터:")
display(cluster_1_data_max_loss_EPI_middle)
# Out:
# 클러스터 1에 속하는 데이터 중에서 가장 큰 수재발생손해액누적값을 가진 데이터:
#                unique_claim_id            계약번호      UY   종목명         수재보험료누적  \
# 17963  C2018031461940-20190920  C2018031461940  201801  종합보험  17,044,316,600
#
#            수재발생손해액누적  수재손해율  claim횟수  클러스터_3개  5-Means
# 17963  1,847,170,929      0        1        2        1

# %%
condition = EPI_middle['수재발생손해액누적'] > 1321919850
condition.sum() # 클러스터 3의 최솟값을 Threshold 로 둘 경우 사고 4개가 추가됨
# Out:
# 29

# %%
display(EPI_middle[condition]) # 클러스터 1에서 2개, 클러스터 4에서 2개가 추가
# Out:
#                                  unique_claim_id            계약번호      UY  \
# 11305                    C2018022432114-20190920  C2018022432114  201801
# 11337                    C2018022434751-20190920  C2018022434751  201801
# 11340                    C2018022434751-20191220  C2018022434751  201801
# 16026                    C2018028932952-20191220  C2018028932952  201801
# 17963                    C2018031461940-20190920  C2018031461940  201801
# 32816                    C2019023021625-20190920  C2019023021625  201901
# 35460                    C2019026246990-20200613  C2019026246990  201901
# 36658                    C2019028757056-20200519  C2019028757056  201901
# 48834                    C2019040930670-20200811  C2019040930670  201901
# 62364                    C2020021232182-20201220  C2020021232182  202001
# 67574                    C2020024648295-20200917  C2020024648295  202001
# 105052                   C2021020532253-20220405  C2021020532253  202101
# 107848                   C2021022211248-20211120  C2021022211248  202101
# 107849                   C2021022211248-20211220  C2021022211248  202101
# 107888                   C2021022249684-20220118  C2021022226158  202101
# 107983                   C2021022261288-20210802  C2021022261288  202101
# 127504                   C2022013141010-20220610  C2022013141010  202201
# 127530                   C2022013141010-20221027  C2022013141010  202201
# 133722                   C2022019176461-20221120  C2022019176461  202201
# 133724                   C2022019176461-20230120  C2022019176461  202201
# 133725                   C2022019176461-20230420  C2022019176461  202201
# 134188                   C2022019713250-20221120  C2022019713250  202201
# 134189                   C2022019713250-20221220  C2022019713250  202201
# 144953                   C2022030305911-20230604  C2022030305911  202201
# 153442                   C2023016868933-20230920  C2023016868933  202301
# 153443                   C2023016868933-20231020  C2023016868933  202301
# 158175  Lotte Chemical Daesan NC Plant Explosion  C2019028757056  201901
# 158931                            Typhoon MAYSAK  C2020024648295  202001
# 159020                            Typhoon MAYSAK  C2020014169766  202001
#
#          종목명        수재보험료누적      수재발생손해액누적  수재손해율  claim횟수  클러스터_3개  5-Means
# 11305   종합보험  6,383,761,574  2,094,332,289      0        1        2        3
# 11337   종합보험  5,846,564,623  1,629,105,300      0        1        2        3
# 11340   종합보험  5,846,564,623 10,224,698,726      2        1        2        2
# 16026   종합보험  5,276,621,542  3,108,693,441      1        1        2        3
# 17963   종합보험 17,044,316,600  1,847,170,929      0        1        2        1
# 32816   종합보험 15,922,823,896  3,350,853,899      0        1        2        3
# 35460   종합보험  5,253,802,693  3,328,110,047      1        1        2        3
# 36658   종합보험  6,180,735,283  2,493,261,974      0        1        2        3
# 48834   종합보험  6,184,647,497  2,955,951,099      0        1        2        3
# 62364   종합보험  4,017,617,122  2,837,504,384      1        1        2        3
# 67574   종합보험  4,325,011,109  2,119,474,644      0        1        2        3
# 105052  종합보험  4,831,393,423  2,779,814,615      1        1        2        3
# 107848  종합보험 12,549,180,890 13,673,317,957      1        1        2        2
# 107849  종합보험 12,549,180,890  1,945,345,470      0        1        2        3
# 107888  종합보험 12,157,810,925  1,813,387,251      0        1        2        3
# 107983  종합보험  7,959,698,086  2,244,632,343      0        1        2        3
# 127504  종합보험  4,825,153,567  1,715,147,629      0        1        2        3
# 127530  종합보험  4,825,153,567  2,332,848,087      0        1        2        3
# 133722  종합보험 12,530,613,560  1,433,627,951      0        1        2        4
# 133724  종합보험 12,530,613,560  1,930,892,838      0        1        2        3
# 133725  종합보험 12,530,613,560  1,427,871,982      0        1        2        4
# 134188  종합보험 12,659,345,285 10,477,305,594      1        1        2        2
# 134189  종합보험 12,659,345,285  1,335,260,708      0        1        2        4
# 144953  종합보험  4,153,343,456  1,396,507,200      0        1        2        3
# 153442  종합보험 13,197,885,637  4,645,042,514      0        1        2        3
# 153443  종합보험 13,197,885,637  8,454,835,659      1        1        2        2
# 158175  종합보험  6,180,735,283  1,346,171,650      0        1        2        3
# 158931  종합보험  4,325,011,109  1,596,748,538      0        1        2        3
# 159020  종합보험 15,209,238,677  1,430,061,720      0        1        2        1

# %%
# 각 클러스터 중심값 출력 (부동소수점 표기법 수정)
클러스터별_중심값_EPI_middle_k5 = pd.DataFrame(scaler_EPI_middle.inverse_transform(kmeans_EPI_middle_k5.cluster_centers_), columns=['수재보험료누적', '수재발생손해액누적'])
# 부동소수점 표기법 수정 및 출력
pd.set_option('display.float_format', lambda x: '{:,.0f}'.format(x))
print("\n각 클러스터 중심값:")
display(클러스터별_중심값_EPI_middle_k5)
# Out:
# 각 클러스터 중심값:
#          수재보험료누적      수재발생손해액누적
# 0  5,322,196,346     64,530,830
# 1 16,700,826,344    176,415,440
# 2 11,063,244,109 10,707,539,484
# 3  7,237,967,194  2,332,654,527
# 4 11,446,532,106    197,600,175

# %% [markdown]
# ✅ 13억 2,191만 원

# %% [markdown]
# ### Elbow Method (EPI high)

# %%
# EPI_high에서 '수재보험료누적', '수재발생손해액누적' 열만 선택
df_EPI_high = EPI_high[['수재보험료누적', '수재발생손해액누적']]

# 데이터 표준화
scaler_EPI_high = StandardScaler()
standardized_EPI_high = scaler_EPI_high.fit_transform(df_EPI_high)

# Elbow Method를 사용하여 적절한 클러스터 개수 찾기
sse_EPI_high = []
K_EPI_high = range(1, 11)
for k_high in K_EPI_high:
    kmeans_EPI_high = KMeans(n_clusters=k_high, random_state=42)
    kmeans_EPI_high.fit(standardized_EPI_high)
    sse_EPI_high.append(kmeans_EPI_high.inertia_)

# Elbow Method 그래프 출력
plt.plot(K_EPI_high, sse_EPI_high, color='lightseagreen', marker='o')
plt.xlabel('클러스터 개수')
plt.ylabel('SSE (Sum of Squared Errors)')
plt.title('Elbow Method (EPI high)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# #### k=5 일 때 k-means (EPI high)

# %%
# K-means 클러스터링 (k=5) - EPI_high 기준
kmeans_EPI_high_k5 = KMeans(n_clusters=5, random_state=42)
clusters_EPI_high_k5 = kmeans_EPI_high_k5.fit_predict(standardized_EPI_high)

# 결과를 데이터프레임에 추가
EPI_high['5-Means'] = clusters_EPI_high_k5

# 클러스터링 결과 시각화
colors_EPI_high_5 = ['paleturquoise', 'bisque', 'palegreen', 'thistle', 'lightcoral']
for cluster_num_EPI in range(5):
    cluster_data_EPI = EPI_high[clusters_EPI_high_k5 == cluster_num_EPI]
    plt.scatter(cluster_data_EPI['수재보험료누적'],
                cluster_data_EPI['수재발생손해액누적'],
                label=f'클러스터 {cluster_num_EPI}', s=50, color=colors_EPI_high_5[cluster_num_EPI])

# 클러스터 중심 플로팅
cluster_centers_2d_EPI_high_k5 = scaler_EPI_high.inverse_transform(kmeans_EPI_high_k5.cluster_centers_)
plt.scatter(cluster_centers_2d_EPI_high_k5[:, 0], cluster_centers_2d_EPI_high_k5[:, 1],
            color='slategrey', marker='X', s=200, label='클러스터 중심')

# 축 레이블 및 그래픽 설정
plt.axhline(y=2314483738	, color='red', linestyle='--', label='Threshold')
plt.xlabel('수재보험료(단위:백억원)')
plt.ylabel('수재발생손해액(단위:백억원)')
plt.title('5개 군집에 대한 K-means 클러스터링 결과 (EPI high)')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-28-4f107f72b963>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EPI_high['5-Means'] = clusters_EPI_high_k5

# %%
# 5개 클러스터에 해당하는 데이터의 개수 알아내기
count_clusters_EPI_high_k5 = []
for cluster_num in range(5):
    count = len(EPI_high[clusters_EPI_high_k5 == cluster_num])
    count_clusters_EPI_high_k5.append(count)
    print(f'클러스터 {cluster_num}에 해당하는 데이터의 개수: {count}')
# Out:
# 클러스터 0에 해당하는 데이터의 개수: 73
# 클러스터 1에 해당하는 데이터의 개수: 10
# 클러스터 2에 해당하는 데이터의 개수: 84
# 클러스터 3에 해당하는 데이터의 개수: 1
# 클러스터 4에 해당하는 데이터의 개수: 1

# %%
# 클러스터 1에 해당하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터 찾기
cluster_1_data_min_loss_EPI_high = EPI_high[EPI_high['5-Means'] == 1].nsmallest(1, '수재발생손해액누적')

# 부동소수점 표기법 수정 및 'e' 제거
cluster_1_data_min_loss_EPI_high['수재발생손해액누적'] = cluster_1_data_min_loss_EPI_high['수재발생손해액누적'].apply(lambda x: '{:,.0f}'.format(x))
cluster_1_data_min_loss_EPI_high['수재보험료누적'] = cluster_1_data_min_loss_EPI_high['수재보험료누적'].apply(lambda x: '{:,.0f}'.format(x))
cluster_1_data_min_loss_EPI_high['수재손해율'] = cluster_1_data_min_loss_EPI_high['수재손해율'].apply(lambda x: '{:,.6f}'.format(x))

# 출력
print("\n클러스터 1에 속하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터:")
display(cluster_1_data_min_loss_EPI_high)
# Out:
# 클러스터 1에 속하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터:
#                unique_claim_id            계약번호      UY   종목명         수재보험료누적  \
# 62343  C2020021232096-20201020  C2020021232096  202001  종합보험  19,927,120,712
#
#            수재발생손해액누적     수재손해율  claim횟수  클러스터_3개  5-Means
# 62343  2,314,483,738  0.116147        1        1        1

# %%
# 각 클러스터 중심값 출력 (부동소수점 표기법 수정)
클러스터별_중심값_EPI_high_k5 = pd.DataFrame(scaler_EPI_high.inverse_transform(kmeans_EPI_high_k5.cluster_centers_), columns=['수재보험료누적', '수재발생손해액누적'])
# 부동소수점 표기법 수정 및 출력
pd.set_option('display.float_format', lambda x: '{:,.0f}'.format(x))
print("\n각 클러스터 중심값:")
display(클러스터별_중심값_EPI_high_k5)
# Out:
# 각 클러스터 중심값:
#          수재보험료누적      수재발생손해액누적
# 0 38,182,952,983    205,596,275
# 1 24,524,973,128  3,994,745,506
# 2 22,432,378,879    327,944,776
# 3 86,185,685,837  3,975,117,985
# 4 37,633,844,586 10,492,500,110

# %% [markdown]
# ✅ 23억 1,448만 원
