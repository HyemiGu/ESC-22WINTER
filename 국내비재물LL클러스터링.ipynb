# %% [markdown]
# <a href="https://colab.research.google.com/github/HyemiGu/ESC-22WINTER/blob/main/%EA%B5%AD%EB%82%B4%EB%B9%84%EC%9E%AC%EB%AC%BCLL%ED%81%B4%EB%9F%AC%EC%8A%A4%ED%84%B0%EB%A7%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 전처리

# %%
# Matplotlib 한글 폰트 설정
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 30 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (20.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 121658 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
# 런타임 다시 시작 후 아래 코드 실행
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
import pandas as pd
import numpy as np

# 엑셀 파일 경로 지정
excel_file_path = '/content/(Indexed) 20240110_국내사고데이터.xlsx'

# 엑셀 파일을 데이터프레임으로 읽기
ttlclaim = pd.read_excel(excel_file_path)

# 데이터프레임 확인
display(ttlclaim)
# Out:
#                                  unique_claim_id            계약번호      UY  \
# 0          2019.07~08 Torrential Rainfall(STATS)  C2019028655442  201901
# 1          2019.07~08 Torrential Rainfall(STATS)  C2019024672398  201901
# 2          2019.07~08 Torrential Rainfall(STATS)  C2019022648225  201901
# 3          2019.07~08 Torrential Rainfall(STATS)  C2019014917987  201901
# 4          2019.07~08 Torrential Rainfall(STATS)  C2019014789929  201901
# ...                                          ...             ...     ...
# 159417                      UAE STORM (MAY 2020)  C2015020859067  201501
# 159418  Yecheon Pumped Storage Power Plant Flood  C2020012141755  202001
# 159419                             농협 BBB 수재 XOL  C2021012373226  202101
# 159420                                 폴라리스쉬핑(주)  C2019017271961  201901
# 159421                                 폴라리스쉬핑(주)  C2019017270850  201901
#
#            종목명      수재보험료       수재발생손해액   UYforIndexing       CPI  \
# 0         종합보험    69690835       2896305           2019  1.145678
# 1         종합보험    97720575       6298932           2019  1.145678
# 2         종합보험   107272821       4466931           2019  1.145678
# 3         종합보험  4933150291        783680           2019  1.145678
# 4         종합보험   122831588        151200           2019  1.145678
# ...        ...         ...           ...            ...       ...
# 159417    기술보험    99044806      12846339           2015  1.201295
# 159418    종합보험   575607015   33808436280           2020  1.139560
# 159419  기타특종보험  1199007600     845074316           2021  1.111788
# 159420    선박보험     6310437   19287917760           2019  1.145678
# 159421    선박보험    51167842  104380794705           2019  1.145678
#
#                  EPI  IncurredLoss  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 0       7.984326e+07  3.318233e+06          NaN          NaN          NaN
# 1       1.119563e+08  7.216548e+06          NaN          NaN          NaN
# 2       1.229001e+08  5.117665e+06          NaN          NaN          NaN
# 3       5.651802e+09  8.978449e+05          NaN          NaN          NaN
# 4       1.407254e+08  1.732265e+05          NaN          NaN          NaN
# ...              ...           ...          ...          ...          ...
# 159417  1.189820e+08  1.543224e+07          NaN          NaN          NaN
# 159418  6.559387e+08  3.852674e+10          NaN          NaN          NaN
# 159419  1.333042e+09  9.395435e+08          NaN          NaN          NaN
# 159420  7.229729e+06  2.209774e+10          NaN          NaN          NaN
# 159421  5.862187e+07  1.195868e+11          NaN          NaN          NaN
#
#         Unnamed: 13 Korea - CPI Unnamed: 15
# 0               NaN          UY       Index
# 1               NaN        2008    1.395562
# 2               NaN        2009    1.358139
# 3               NaN        2010    1.319347
# 4               NaN        2011    1.268292
# ...             ...         ...         ...
# 159417          NaN         NaN         NaN
# 159418          NaN         NaN         NaN
# 159419          NaN         NaN         NaN
# 159420          NaN         NaN         NaN
# 159421          NaN         NaN         NaN
#
# [159422 rows x 16 columns]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
ttlclaim.info()
ttlclaim.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159422 entries, 0 to 159421
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   unique_claim_id  159422 non-null  object
#  1   계약번호             159422 non-null  object
#  2   UY               159422 non-null  int64
#  3   종목명              159422 non-null  object
#  4    수재보험료           159422 non-null  object
#  5    수재발생손해액         159422 non-null  object
#  6   UY               159422 non-null  int64
#  7   CPI              159397 non-null  float64
#  8   EPI              155848 non-null  float64
#  9   IncurredLoss     156925 non-null  float64
#  10  Unnamed: 10      0 non-null       float64
#  11  Unnamed: 11      0 non-null       float64
#  12  Unnamed: 12      0 non-null       float64
#  13  Unnamed: 13      0 non-null       float64
#  14  Korea - CPI      18 non-null      object
#  15  Unnamed: 15      18 non-null      object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 19.5+ MB
# Index(['unique_claim_id', '계약번호', 'UY', '종목명', ' 수재보험료 ', ' 수재발생손해액 ', 'UY ',
#        'CPI ', 'EPI ', 'IncurredLoss ', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Korea - CPI', 'Unnamed: 15'],
#       dtype='object')

# %%
# 수재보험료와 수재발생손해액 열을 숫자형으로 변환(문자열 " - "은 NaN으로 대체)
ttlclaim['EPI'] = pd.to_numeric(ttlclaim['EPI'], errors='coerce')
ttlclaim['IncurredLoss'] = pd.to_numeric(ttlclaim['IncurredLoss'], errors='coerce')

# %% [markdown]
# ## 국내 비재물 클러스터링

# %%
ttlclaim['종목명'].unique()
# Out:
# array(['종합보험', '기술보험', '기타특종보험', '적하보험', '일반배상책임보험', '전문배상책임보험', '신종종합보험',
#        '선박보험', '상해보험', '항공보험', '보증보험', '화재보험'], dtype=object)

# %%
# 주어진 데이터프레임 (ttlclaim)에서 '종목명'이 비재물보험인 보종만 선택
selected_rows = ttlclaim[ttlclaim['종목명'].isin(['기술보험', '기타특종보험', '적하보험', '일반배상책임보험', '전문배상책임보험', '신종종합보험',
       '선박보험', '상해보험', '항공보험', '보증보험'])]

# 새로운 데이터프레임 생성 (NonProPerty)
NPP = pd.DataFrame(selected_rows)

# 결과 확인
display(NPP)
# Out:
#                               unique_claim_id            계약번호      UY     종목명  \
# 12      2019.07~08 Torrential Rainfall(STATS)  C2018026278750  201801    기술보험
# 13      2019.07~08 Torrential Rainfall(STATS)  C2017026631049  201701    기술보험
# 14      2019.07~08 Torrential Rainfall(STATS)  C2016028910852  201601    기술보험
# 15      2019.07~08 Torrential Rainfall(STATS)  C2008040248874  200804    기술보험
# 16                  2020 CHINA SOUTHERN FLOOD  C2020022783508  201901    기술보험
# ...                                       ...             ...     ...     ...
# 159416                 UAE STORM (MARCH 2020)  C2013020398449  201204    기술보험
# 159417                   UAE STORM (MAY 2020)  C2015020859067  201501    기술보험
# 159419                          농협 BBB 수재 XOL  C2021012373226  202101  기타특종보험
# 159420                              폴라리스쉬핑(주)  C2019017271961  201901    선박보험
# 159421                              폴라리스쉬핑(주)  C2019017270850  201901    선박보험
#
#             수재보험료       수재발생손해액   UYforIndexing       CPI           EPI  \
# 12        59334000       3190000           2018  1.150072  6.823837e+07
# 13      1217124940        544244           2017  1.167044  1.420438e+09
# 14      1027786932        362371           2016  1.189731  1.222790e+09
# 15       779197869        157600           2008  1.395562  1.087419e+09
# 16       207217601       4682384           2019  1.145678  2.374046e+08
# ...            ...           ...            ...       ...           ...
# 159416    90929165        177245           2012  1.241148  1.128566e+08
# 159417    99044806      12846339           2015  1.201295  1.189820e+08
# 159419  1199007600     845074316           2021  1.111788  1.333042e+09
# 159420     6310437   19287917760           2019  1.145678  7.229729e+06
# 159421    51167842  104380794705           2019  1.145678  5.862187e+07
#
#         IncurredLoss  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 12      3.668730e+06          NaN          NaN          NaN          NaN
# 13      6.351567e+05          NaN          NaN          NaN          NaN
# 14      4.311240e+05          NaN          NaN          NaN          NaN
# 15      2.199406e+05          NaN          NaN          NaN          NaN
# 16      5.364504e+06          NaN          NaN          NaN          NaN
# ...              ...          ...          ...          ...          ...
# 159416  2.199873e+05          NaN          NaN          NaN          NaN
# 159417  1.543224e+07          NaN          NaN          NaN          NaN
# 159419  9.395435e+08          NaN          NaN          NaN          NaN
# 159420  2.209774e+10          NaN          NaN          NaN          NaN
# 159421  1.195868e+11          NaN          NaN          NaN          NaN
#
#        Korea - CPI Unnamed: 15
# 12            2019    1.145678
# 13            2020     1.13956
# 14            2021    1.111788
# 15            2022     1.05796
# 16            2023    1.022981
# ...            ...         ...
# 159416         NaN         NaN
# 159417         NaN         NaN
# 159419         NaN         NaN
# 159420         NaN         NaN
# 159421         NaN         NaN
#
# [151009 rows x 16 columns]

# %%
# claim 횟수 계산 및 데이터 정리
NPP['claim횟수'] = NPP.groupby(['unique_claim_id', '계약번호']).cumcount() + 1
NPP['수재보험료누적'] = NPP.groupby(['unique_claim_id', '계약번호'])['EPI'].cumsum()
NPP['수재발생손해액누적'] = NPP.groupby(['unique_claim_id', '계약번호'])['IncurredLoss'].cumsum()

# '수재발생손해액누적' / '수재보험료누적'를 계산하여 '수재손해율' 열 추가
NPP['수재손해율'] = NPP['수재발생손해액누적'] / NPP['수재보험료누적']

# 사고빈도 1로 초기화
NPP['claim횟수'] = 1

# 중복된 데이터 삭제
NPP_for_analysis = NPP.drop_duplicates(subset=['unique_claim_id', '계약번호'], keep='last')

# 필요한 열만 선택
NPP_for_analysis = NPP_for_analysis[['unique_claim_id', '계약번호', 'UY', '종목명', '수재보험료누적', '수재발생손해액누적', '수재손해율', 'claim횟수']]

display(NPP_for_analysis)
# Out:
#                               unique_claim_id            계약번호      UY     종목명  \
# 12      2019.07~08 Torrential Rainfall(STATS)  C2018026278750  201801    기술보험
# 13      2019.07~08 Torrential Rainfall(STATS)  C2017026631049  201701    기술보험
# 14      2019.07~08 Torrential Rainfall(STATS)  C2016028910852  201601    기술보험
# 15      2019.07~08 Torrential Rainfall(STATS)  C2008040248874  200804    기술보험
# 16                  2020 CHINA SOUTHERN FLOOD  C2020022783508  201901    기술보험
# ...                                       ...             ...     ...     ...
# 159416                 UAE STORM (MARCH 2020)  C2013020398449  201204    기술보험
# 159417                   UAE STORM (MAY 2020)  C2015020859067  201501    기술보험
# 159419                          농협 BBB 수재 XOL  C2021012373226  202101  기타특종보험
# 159420                              폴라리스쉬핑(주)  C2019017271961  201901    선박보험
# 159421                              폴라리스쉬핑(주)  C2019017270850  201901    선박보험
#
#              수재보험료누적     수재발생손해액누적        수재손해율  claim횟수
# 12      6.823837e+07  3.668730e+06     0.053763        1
# 13      1.420438e+09  6.351567e+05     0.000447        1
# 14      1.222790e+09  4.311240e+05     0.000353        1
# 15      1.087419e+09  2.199406e+05     0.000202        1
# 16      2.374046e+08  5.364504e+06     0.022596        1
# ...              ...           ...          ...      ...
# 159416  1.128566e+08  2.199873e+05     0.001949        1
# 159417  1.189820e+08  1.543224e+07     0.129702        1
# 159419  1.333042e+09  9.395435e+08     0.704811        1
# 159420  7.229729e+06  2.209774e+10  3056.510628        1
# 159421  5.862187e+07  1.195868e+11  2039.968672        1
#
# [150932 rows x 8 columns]

# %%
NPP_for_analysis['claim횟수'].max()
# Out:
# 1

# %% [markdown]
# ## 결측치 및 음수 처리

# %%
NPP_for_analysis['수재발생손해액누적'].isna().value_counts()
# Out:
# False    148559
# True       2373
# Name: 수재발생손해액누적, dtype: int64

# %%
NPP_for_analysis['수재보험료누적'].isna().value_counts()
# Out:
# False    147553
# True       3379
# Name: 수재보험료누적, dtype: int64

# %%
NPP_for_analysis.describe()
# Out:
#            UY         수재보험료누적       수재발생손해액누적         수재손해율  claim횟수
# count 150,932         147,553         148,559       145,698  150,932
# mean  202,002     689,655,517      20,769,018        85,600        1
# std       179   3,583,145,541     494,008,781    15,575,887        0
# min   200,204    -326,316,556  -4,359,308,430  -133,758,450        1
# 25%   201,901       6,825,841         157,467             0        1
# 50%   202,001      64,874,329         567,501             0        1
# 75%   202,101     340,663,120       2,067,852             0        1
# max   202,305 105,928,377,009 119,586,780,116 4,353,904,235        1

# %%
# NaN 값이 있는 행 제외
df = NPP_for_analysis.dropna(subset=['수재발생손해액누적', '수재보험료누적', '수재손해율'])

# 음수 값이 있는 행 제외
df = df[(df['수재발생손해액누적'] >= 0) & (df['수재보험료누적'] >= 0) & (df['수재손해율'] >= 0)]

# %%
df.isna().value_counts()
# Out:
# unique_claim_id  계약번호   UY     종목명    수재보험료누적  수재발생손해액누적  수재손해율  claim횟수
# False            False  False  False  False    False      False  False      144034
# dtype: int64

# %%
150932-144034 # 개의 데이터 제외
# Out:
# 6898

# %%
df.describe()
# Out:
#            UY         수재보험료누적       수재발생손해액누적         수재손해율  claim횟수
# count 144,034         144,034         144,034       144,034  144,034
# mean  202,007     663,679,413      21,278,212        87,723        1
# std       171   3,380,284,645     501,093,295    15,661,502        0
# min   200,804               1               1             0        1
# 25%   201,901       7,295,216         163,677             0        1
# 50%   202,001      65,526,204         577,123             0        1
# 75%   202,101     337,384,568       2,096,396             0        1
# max   202,305 105,928,377,009 119,586,780,116 4,353,904,235        1

# %% [markdown]
# ## Outlier 제외

# %%
# 보험료와 손해액 outliers 필터링 based on z-score
z_score_threshold = 3
outlier_mask1 = (df['수재발생손해액누적'] - df['수재발생손해액누적'].mean()) / df['수재발생손해액누적'].std() > z_score_threshold
df_no_outliers1 = df[~outlier_mask1]

outlier_mask2 = (df['수재보험료누적'] - df['수재보험료누적'].mean()) / df['수재보험료누적'].std() > z_score_threshold
df_no_outliers = df_no_outliers1[~outlier_mask2]
# Out:
# <ipython-input-7-f1a7ebcc88af>:7: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_no_outliers = df_no_outliers1[~outlier_mask2]

# %%
df_no_outliers1.describe()
# Out:
#            UY         수재보험료누적     수재발생손해액누적       수재손해율  claim횟수
# count 143,813         143,813       143,813     143,813  143,813
# mean  202,007     652,415,083    11,640,409       9,287        1
# std       171   3,310,287,718    69,804,132   1,501,201        0
# min   200,804               1             1           0        1
# 25%   201,901       7,241,475       163,375           0        1
# 50%   202,001      65,526,204       574,689           0        1
# 75%   202,101     337,113,474     2,079,511           0        1
# max   202,305 105,928,377,009 1,521,612,409 418,371,126        1

# %%
144034-143813

# 발생손해액 아웃라이어는 총 144034 - 143813 = 221개
# Out:
# 221

# %%
143813-142186
# Out:
# 1627

# %%
df_no_outliers.describe()

# 보험료까지 포함하면 아웃라이어 총 1848 (=221+1627) 개 제외
# Out:
#            UY        수재보험료누적     수재발생손해액누적       수재손해율  claim횟수
# count 142,186        142,186       142,186     142,186  142,186
# mean  202,009    364,801,883     9,122,770       9,394        1
# std       169    904,872,798    55,385,814   1,509,765        0
# min   200,804              1             1           0        1
# 25%   201,901      6,939,689       162,160           0        1
# 50%   202,001     63,019,034       568,754           0        1
# 75%   202,101    332,019,513     2,017,021           0        1
# max   202,305 10,452,982,069 1,521,612,409 418,371,126        1

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Elbow Method (EPI 구간의 개수 설정)

# %%
# 아웃라이어 제거한 df 에서 보험료 열만 사용
EPI = df_no_outliers[['수재보험료누적']]

# EPI 표준화
scaler_EPI = StandardScaler()
standardized_EPI = scaler_EPI.fit_transform(EPI)

# Elbow Method 사용하여 적절한 클러스터 개수 찾기
sse_EPI =[]
K_range = range(1,11)
for K_EPI in K_range:
  kmeans_EPI = KMeans(n_clusters=K_EPI, random_state=42)
  kmeans_EPI.fit(standardized_EPI)
  sse_EPI.append(kmeans_EPI.inertia_)

# Elbow Method 그래프 출력
plt.plot(K_range, sse_EPI, marker='o')
plt.xlabel('클러스터 개수')
plt.ylabel('SSE (Sum of Squared Errors)')
plt.title('Elbow Method (EPI 구간 개수)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# #### EPI 구간이 3개일 때 k-means

# %%
from sklearn.preprocessing import StandardScaler

# StandardScaler 초기화
scaler = StandardScaler()

# 데이터를 표준화
standardized_EPI = scaler.fit_transform(EPI)

# K-means 클러스터링 (k=3)
kmeans_EPI_3 = KMeans(n_clusters=3, random_state=42)
clusters_EPI_3 = kmeans_EPI_3.fit_predict(standardized_EPI)

# 결과를 데이터프레임에 추가
df_no_outliers['클러스터_3개'] = clusters_EPI_3

# 클러스터 중심을 원래의 스케일로 변환
cluster_centers_original_scale = scaler.inverse_transform(kmeans_EPI_3.cluster_centers_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-10-9e28f9ee2d6c>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_outliers['클러스터_3개'] = clusters_EPI_3

# %%
df_no_outliers
# Out:
#                               unique_claim_id            계약번호      UY     종목명  \
# 12      2019.07~08 Torrential Rainfall(STATS)  C2018026278750  201801    기술보험
# 13      2019.07~08 Torrential Rainfall(STATS)  C2017026631049  201701    기술보험
# 14      2019.07~08 Torrential Rainfall(STATS)  C2016028910852  201601    기술보험
# 15      2019.07~08 Torrential Rainfall(STATS)  C2008040248874  200804    기술보험
# 16                  2020 CHINA SOUTHERN FLOOD  C2020022783508  201901    기술보험
# ...                                       ...             ...     ...     ...
# 159414                   UAE STORM (JAN 2020)  C2008040610894  200804    기술보험
# 159415                 UAE STORM (MARCH 2020)  C2018019359232  201601    기술보험
# 159416                 UAE STORM (MARCH 2020)  C2013020398449  201204    기술보험
# 159417                   UAE STORM (MAY 2020)  C2015020859067  201501    기술보험
# 159419                          농협 BBB 수재 XOL  C2021012373226  202101  기타특종보험
#
#              수재보험료누적   수재발생손해액누적  수재손해율  claim횟수  클러스터_3개
# 12        68,238,372   3,668,730      0        1        0
# 13     1,420,438,358     635,157      0        1        2
# 14     1,222,789,974     431,124      0        1        2
# 15     1,087,418,936     219,941      0        1        2
# 16       237,404,647   5,364,504      0        1        0
# ...              ...         ...    ...      ...      ...
# 159414   549,998,991     317,842      0        1        0
# 159415   261,754,002   1,239,939      0        1        0
# 159416   112,856,551     219,987      0        1        0
# 159417   118,982,030  15,432,243      0        1        0
# 159419 1,333,042,262 939,543,484      1        1        2
#
# [142186 rows x 9 columns]

# %%
colors_3개 = ['paleturquoise', 'lightpink', 'wheat']
for cluster_num_EPI in range(3):
    cluster_data_EPI = EPI[clusters_EPI_3 == cluster_num_EPI]
    plt.scatter(cluster_data_EPI['수재보험료누적'],
                [cluster_num_EPI] * len(cluster_data_EPI),
                label=f'클러스터 {cluster_num_EPI}', s=50, color=colors_3개[cluster_num_EPI])

# 클러스터 중심 플로팅
plt.scatter( cluster_centers_original_scale[:, 0], [0, 1, 2], # y 값을 클러스터 인덱스로 지정
            color='slategrey', marker='X', s=200, label='클러스터 중심')

# 축 레이블 및 그래픽 설정
plt.xlabel('수재보험료(단위:백억)')
plt.ylabel('클러스터 인덱스')
plt.title('3개 군집에 대한 K-means 클러스터링 결과 (EPI 구간 개수)')
plt.legend()
plt.show()

# %%
# 클러스터 0에 해당하는 수재보험료 데이터의 최솟값
cluster_0_data_EPI = EPI[clusters_EPI_3 == 0]  # 클러스터 0에 해당하는 데이터 선택
max_value_cluster_0 = cluster_0_data_EPI['수재보험료누적'].max()  # 선택된 데이터에서 '수재보험료누적' 열의 최솟값 계산
print(f'클러스터 0에 해당하는 수재보험료 데이터의 최댓값: {max_value_cluster_0}')

# 클러스터 2에 해당하는 수재보험료 데이터의 최솟값
cluster_2_data_EPI = EPI[clusters_EPI_3 == 2]  # 클러스터 2에 해당하는 데이터 선택
min_value_cluster_2 = cluster_2_data_EPI['수재보험료누적'].min()  # 선택된 데이터에서 '수재보험료누적' 열의 최솟값 계산
print(f'클러스터 2에 해당하는 수재보험료 데이터의 최솟값: {min_value_cluster_2}')

# 클러스터 2에 해당하는 수재보험료 데이터의 최솟값
cluster_2_data_EPI = EPI[clusters_EPI_3 == 2]  # 클러스터 2에 해당하는 데이터 선택
max_value_cluster_2 = cluster_2_data_EPI['수재보험료누적'].max()  # 선택된 데이터에서 '수재보험료누적' 열의 최댓값 계산
print(f'클러스터 2에 해당하는 수재보험료 데이터의 최댓값: {max_value_cluster_2}')

# 클러스터 1에 해당하는 수재보험료 데이터의 최솟값
cluster_1_data_EPI = EPI[clusters_EPI_3 == 1]  # 클러스터 1에 해당하는 데이터 선택
min_value_cluster_1 = cluster_1_data_EPI['수재보험료누적'].min()  # 선택된 데이터에서 '수재보험료누적' 열의 최솟값 계산
print(f'클러스터 1에 해당하는 수재보험료 데이터의 최솟값: {min_value_cluster_1}')

# 클러스터 1에 해당하는 수재보험료 데이터의 최솟값
cluster_1_data_EPI = EPI[clusters_EPI_3 == 1]  # 클러스터 1에 해당하는 데이터 선택
max_value_cluster_1 = cluster_1_data_EPI['수재보험료누적'].max()  # 선택된 데이터에서 '수재보험료누적' 열의 최댓값 계산
print(f'클러스터 1에 해당하는 수재보험료 데이터의 최댓값: {max_value_cluster_1}')

# %% [markdown]
# *   cluster 0 가 EPI low
# *   cluster 1 가 EPI high
# *   cluster 2 가 EPI middle

# %%
# 클러스터 0에 해당하는 데이터의 개수
count_cluster_0 = len(EPI[clusters_EPI_3 == 0])
print(f'클러스터 0에 해당하는 데이터의 개수: {count_cluster_0}')

# 클러스터 1에 해당하는 데이터의 개수
count_cluster_1 = len(EPI[clusters_EPI_3 == 1])
print(f'클러스터 1에 해당하는 데이터의 개수: {count_cluster_1}')

# 클러스터 2에 해당하는 데이터의 개수
count_cluster_2 = len(EPI[clusters_EPI_3 == 2])
print(f'클러스터 2에 해당하는 데이터의 개수: {count_cluster_2}')
# Out:
# 클러스터 0에 해당하는 데이터의 개수: 130081
# 클러스터 1에 해당하는 데이터의 개수: 1735
# 클러스터 2에 해당하는 데이터의 개수: 10370

# %%
# 클러스터에 따라 데이터 분류
EPI_low = df_no_outliers[df_no_outliers['클러스터_3개'] == 0]
EPI_middle = df_no_outliers[df_no_outliers['클러스터_3개'] == 2]
EPI_high = df_no_outliers[df_no_outliers['클러스터_3개'] == 1]


# 저장된 데이터프레임 확인
print("EPI_low:")
display(EPI_low.head())

print("\nEPI_middle:")
display(EPI_middle.head())

print("\nEPI_high:")
display(EPI_high.head())
# Out:
# EPI_low:
#                           unique_claim_id            계약번호      UY   종목명  \
# 12  2019.07~08 Torrential Rainfall(STATS)  C2018026278750  201801  기술보험
# 16              2020 CHINA SOUTHERN FLOOD  C2020022783508  201901  기술보험
# 17              2020 CHINA SOUTHERN FLOOD  C2020016446738  201901  기술보험
# 18              2020 CHINA SOUTHERN FLOOD  C2020016445552  201901  기술보험
# 19              2020 CHINA SOUTHERN FLOOD  C2019036591531  201701  기술보험
#
#          수재보험료누적     수재발생손해액누적     수재손해율  claim횟수  클러스터_3개
# 12  6.823837e+07  3.668730e+06  0.053763        1        0
# 16  2.374046e+08  5.364504e+06  0.022596        1        0
# 17  4.276613e+08  1.011634e+04  0.000024        1        0
# 18  1.436336e+07  1.809846e+07  1.260044        1        0
# 19  5.091896e+08  3.941141e+07  0.077400        1        0
# EPI_middle:
#                           unique_claim_id            계약번호      UY   종목명  \
# 13  2019.07~08 Torrential Rainfall(STATS)  C2017026631049  201701  기술보험
# 14  2019.07~08 Torrential Rainfall(STATS)  C2016028910852  201601  기술보험
# 15  2019.07~08 Torrential Rainfall(STATS)  C2008040248874  200804  기술보험
# 21              2020 CHINA SOUTHERN FLOOD  C2019022419467  201901  기술보험
# 75             202007~08 Monsoon Rainfall  C2020024149170  202001  기술보험
#
#          수재보험료누적     수재발생손해액누적     수재손해율  claim횟수  클러스터_3개
# 13  1.420438e+09  6.351567e+05  0.000447        1        2
# 14  1.222790e+09  4.311240e+05  0.000353        1        2
# 15  1.087419e+09  2.199406e+05  0.000202        1        2
# 21  1.214304e+09  8.028065e+06  0.006611        1        2
# 75  2.955076e+09  4.654439e+08  0.157507        1        2
# EPI_high:
#                 unique_claim_id            계약번호      UY   종목명       수재보험료누적  \
# 317  202007~08 Monsoon Rainfall  C2016012863952  201501  기술보험  7.769360e+09
# 320  202007~08 Monsoon Rainfall  C2015022631057  201501  기술보험  6.522859e+09
# 325  202007~08 Monsoon Rainfall  C2015011638495  201401  기술보험  7.335643e+09
# 349        2021 Monsoon (Stats)  C2017012985252  201601  기술보험  6.847708e+09
# 350        2021 Monsoon (Stats)  C2016012863952  201501  기술보험  7.769360e+09
#
#         수재발생손해액누적     수재손해율  claim횟수  클러스터_3개
# 317  5.720446e+07  0.007363        1        1
# 320  1.960841e+08  0.030061        1        1
# 325  7.984515e+07  0.010885        1        1
# 349  3.708927e+05  0.000054        1        1
# 350  1.355972e+07  0.001745        1        1

# %% [markdown]
# ### EPI 구간 별 클러스터링

# %% [markdown]
# #### Elbow Method (epi low)

# %%
# EPI low 에서 '수재보험료누적', '수재발생손해액누적' 열만 사용
df_EPI_low = EPI_low[['수재보험료누적', '수재발생손해액누적']]

# 데이터 표준화
scaler_EPI_low = StandardScaler()
standardized_EPI_low = scaler_EPI_low.fit_transform(df_EPI_low)

# Elbow Method를 사용하여 적절한 클러스터 개수 찾기
sse_EPI_low = []
K_EPI_low = range(1, 11)
for k_low in K_EPI_low:
    kmeans_EPI_low = KMeans(n_clusters=k_low, random_state=42)
    kmeans_EPI_low.fit(standardized_EPI_low)
    sse_EPI_low.append(kmeans_EPI_low.inertia_)

# Elbow Method 그래프 출력
plt.plot(K_EPI_low, sse_EPI_low, color = 'lightseagreen', marker='o')
plt.xlabel('클러스터 개수')
plt.ylabel('SSE (Sum of Squared Errors)')
plt.title('Elbow Method (EPI low)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# #### k = 5 일 때 k-means

# %%
# K-means 클러스터링 (k=5)
kmeans_EPI_low_5 = KMeans(n_clusters=5, random_state=42)
clusters_EPI_low_5 = kmeans_EPI_low_5.fit_predict(standardized_EPI_low)

# 결과를 데이터프레임에 추가
EPI_low['5-Means'] = clusters_EPI_low_5
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-14-1b2861694946>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EPI_low['5-Means'] = clusters_EPI_low_5

# %%
# 각 클러스터에 대해 데이터 포인트를 2차원 평면에 플로팅
colors_EPI_low_5 = ['paleturquoise', 'bisque', 'palegreen', 'thistle', 'lightcoral']
for cluster_num_EPI_low_5 in range(5):
    cluster_data_EPI_low_5 = EPI_low[clusters_EPI_low_5 == cluster_num_EPI_low_5]
    plt.scatter(cluster_data_EPI_low_5['수재보험료누적'], cluster_data_EPI_low_5['수재발생손해액누적'],
                label=f'클러스터 {cluster_num_EPI_low_5}', s=50, color=colors_EPI_low_5[cluster_num_EPI_low_5])

# 클러스터 중심 플로팅
cluster_centers_2d_EPI_low_5 = scaler_EPI_low.inverse_transform(kmeans_EPI_low_5.cluster_centers_)
plt.scatter(cluster_centers_2d_EPI_low_5[:, 0], cluster_centers_2d_EPI_low_5[:, 1],
            color='slategrey', marker='X', s=200, label='클러스터 중심')

# 축 레이블 및 그래픽 설정
plt.axhline(y=126553289, color='red', linestyle='--', label='Threshold')
plt.xlabel('수재보험료(단위:십억원)')
plt.ylabel('수재발생손해액(단위:십억원)')
plt.title('5개 군집에 대한 K-means 클러스터링 결과 (EPI low)')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 5개 클러스터에 해당하는 데이터의 개수 알아내기
count_clusters_EPI_low_k5 = []
for cluster_num in range(5):
    count = len(EPI_low[clusters_EPI_low_5 == cluster_num])
    count_clusters_EPI_low_k5.append(count)
    print(f'클러스터 {cluster_num}에 해당하는 데이터의 개수: {count}')
# Out:
# 클러스터 0에 해당하는 데이터의 개수: 92301
# 클러스터 1에 해당하는 데이터의 개수: 13342
# 클러스터 2에 해당하는 데이터의 개수: 840
# 클러스터 3에 해당하는 데이터의 개수: 23391
# 클러스터 4에 해당하는 데이터의 개수: 207

# %%
# 원하는 열 선택
선택된_열 = ['수재보험료누적', '수재발생손해액누적']

# 각 클러스터 중심값 출력 (부동소수점 표기법 수정)
클러스터별_중심값 = pd.DataFrame(scaler_EPI_low.inverse_transform(kmeans_EPI_low_5.cluster_centers_), columns=선택된_열)
# 부동소수점 표기법 수정 및 출력
pd.set_option('display.float_format', lambda x: '{:,.0f}'.format(x))
print("\n각 클러스터 중심값:")
display(클러스터별_중심값)
# Out:
# 각 클러스터 중심값:
#       수재보험료누적   수재발생손해액누적
# 0  37,749,732   1,870,057
# 1 741,001,080   6,640,755
# 2 291,459,576 245,456,474
# 3 305,266,830   5,490,006
# 4 301,155,573 836,116,717

# %%
# 클러스터 2에 해당하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터 찾기
cluster_2_data_min_loss_EPI_low = EPI_low[EPI_low['5-Means'] == 2].nsmallest(1, '수재발생손해액누적')

# 부동소수점 표기법 수정 및 'e' 제거
cluster_2_data_min_loss_EPI_low['수재발생손해액누적'] = cluster_2_data_min_loss_EPI_low['수재발생손해액누적'].apply(lambda x: '{:,.0f}'.format(x))
cluster_2_data_min_loss_EPI_low['수재보험료누적'] = cluster_2_data_min_loss_EPI_low['수재보험료누적'].apply(lambda x: '{:,.0f}'.format(x))

# 출력
print("\n클러스터 2에 속하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터:")
display(cluster_2_data_min_loss_EPI_low)
# Out:
# 클러스터 2에 속하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터:
#                 unique_claim_id            계약번호      UY     종목명     수재보험료누적  \
# 119027  C2021028093330-20211117  C2021028092074  202101  기타특종보험  90,439,705
#
#           수재발생손해액누적  수재손해율  claim횟수  클러스터_3개  5-Means
# 119027  126,553,289      1        1        0        2

# %%
condition = EPI_low['수재발생손해액누적'] > 126553289
condition.sum() # 클러스터 2의 최솟값을 Threshold 로 둘 경우 1083-(840+207) = 36개 사고가 추가됨
# Out:
# 1083

# %%
1083/130081
# Out:
# 0.008325581752907804

# %% [markdown]
# ✅ 1억 2,655만원

# %% [markdown]
# #### Elbow Method (epi middle)

# %%
# EPI_middle에서 '수재보험료누적', '수재발생손해액누적' 열만 선택
df_EPI_middle = EPI_middle[['수재보험료누적', '수재발생손해액누적']]

# 데이터 표준화
scaler_EPI_middle = StandardScaler()
standardized_EPI_middle = scaler_EPI_middle.fit_transform(df_EPI_middle)

# Elbow Method를 사용하여 적절한 클러스터 개수 찾기
sse_EPI_middle = []
K_EPI_middle = range(1, 11)
for k_middle in K_EPI_middle:
    kmeans_EPI_middle = KMeans(n_clusters=k_middle, random_state=42)
    kmeans_EPI_middle.fit(standardized_EPI_middle)
    sse_EPI_middle.append(kmeans_EPI_middle.inertia_)

# Elbow Method 그래프 출력
plt.plot(K_EPI_middle, sse_EPI_middle, color='lightseagreen', marker='o')
plt.xlabel('클러스터 개수')
plt.ylabel('SSE (Sum of Squared Errors)')
plt.title('Elbow Method (EPI middle)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# #### k = 5 일 때 k-means

# %%
# K-means 클러스터링 (k=5) - EPI_middle 기준
kmeans_EPI_middle_k5 = KMeans(n_clusters=5, random_state=42)
clusters_EPI_middle_k5 = kmeans_EPI_middle_k5.fit_predict(standardized_EPI_middle)

# 결과를 데이터프레임에 추가
EPI_middle['5-Means'] = clusters_EPI_middle_k5

# 클러스터링 결과 시각화
colors_EPI_middle_5 = ['paleturquoise', 'lightcoral', 'bisque', 'thistle', 'palegreen']
for cluster_num_EPI in range(5):
    cluster_data_EPI = EPI_middle[clusters_EPI_middle_k5 == cluster_num_EPI]
    plt.scatter(cluster_data_EPI['수재보험료누적'],
                cluster_data_EPI['수재발생손해액누적'],
                label=f'클러스터 {cluster_num_EPI}', s=50, color=colors_EPI_middle_5[cluster_num_EPI])

# 클러스터 중심 플로팅
cluster_centers_2d_EPI_middle_k5 = scaler_EPI_middle.inverse_transform(kmeans_EPI_middle_k5.cluster_centers_)
plt.scatter(cluster_centers_2d_EPI_middle_k5[:, 0], cluster_centers_2d_EPI_middle_k5[:, 1],
            color='slategrey', marker='X', s=200, label='클러스터 중심')

# 축 레이블 및 그래픽 설정
plt.axhline(y=191382520, color='red', linestyle='--', label='Threshold')
plt.xlabel('수재보험료누적(단위:십억원)')
plt.ylabel('수재발생손해액누적(단위:십억원)')
plt.title('5개 군집에 대한 K-means 클러스터링 결과 (EPI middle)')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-53-dabda1e79f2f>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EPI_middle['5-Means'] = clusters_EPI_middle_k5

# %%
# 5개 클러스터에 해당하는 데이터의 개수 알아내기
count_clusters_EPI_middle_k5 = []
for cluster_num in range(5):
    count = len(EPI_middle[clusters_EPI_middle_k5 == cluster_num])
    count_clusters_EPI_middle_k5.append(count)
    print(f'클러스터 {cluster_num}에 해당하는 데이터의 개수: {count}')
# Out:
# 클러스터 0에 해당하는 데이터의 개수: 6061
# 클러스터 1에 해당하는 데이터의 개수: 2569
# 클러스터 2에 해당하는 데이터의 개수: 71
# 클러스터 3에 해당하는 데이터의 개수: 307
# 클러스터 4에 해당하는 데이터의 개수: 1362

# %%
# 클러스터 3에 해당하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터 찾기
cluster_3_data_min_loss_EPI_middle = EPI_middle[EPI_middle['5-Means'] == 3].nsmallest(1, '수재발생손해액누적')

# 부동소수점 표기법 수정 및 'e' 제거
cluster_3_data_min_loss_EPI_middle['수재발생손해액누적'] = cluster_3_data_min_loss_EPI_middle['수재발생손해액누적'].apply(lambda x: '{:,.0f}'.format(x))
cluster_3_data_min_loss_EPI_middle['수재보험료누적'] = cluster_3_data_min_loss_EPI_middle['수재보험료누적'].apply(lambda x: '{:,.0f}'.format(x))

# 출력
print("\n클러스터 3에 속하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터:")
display(cluster_3_data_min_loss_EPI_middle)
# Out:
# 클러스터 3에 속하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터:
#                 unique_claim_id            계약번호      UY     종목명  \
# 119289  C2021028988742-20230701  C2021028988742  202101  기타특종보험
#
#               수재보험료누적    수재발생손해액누적  수재손해율  claim횟수  클러스터_3개  5-Means
# 119289  2,229,912,109  191,382,520      0        1        2        3

# %%
# 클러스터 4에 해당하는 데이터 중에서 가장 큰 수재발생손해액누적값을 가진 데이터 찾기
cluster_4_data_max_loss_EPI_middle = EPI_middle[EPI_middle['5-Means'] == 4].nlargest(1, '수재발생손해액누적')

# 부동소수점 표기법 수정 및 'e' 제거
cluster_4_data_max_loss_EPI_middle['수재발생손해액누적'] = cluster_4_data_max_loss_EPI_middle['수재발생손해액누적'].apply(lambda x: '{:,.0f}'.format(x))
cluster_4_data_max_loss_EPI_middle['수재보험료누적'] = cluster_4_data_max_loss_EPI_middle['수재보험료누적'].apply(lambda x: '{:,.0f}'.format(x))

# 출력
print("\n클러스터 4에 속하는 데이터 중에서 가장 큰 수재발생손해액누적값을 가진 데이터:")
display(cluster_4_data_max_loss_EPI_middle)
# Out:
# 클러스터 4에 속하는 데이터 중에서 가장 큰 수재발생손해액누적값을 가진 데이터:
#               unique_claim_id            계약번호      UY   종목명        수재보험료누적  \
# 2083  C2015014269868-20191201  C2015014269868  201204  기술보험  4,079,995,937
#
#         수재발생손해액누적  수재손해율  claim횟수  클러스터_3개  5-Means
# 2083  250,690,990      0        1        2        4

# %%
condition_middle = EPI_middle['수재발생손해액누적'] > 191382520
condition_middle.sum()
# Out:
# 409

# %%
# 클러스터 0, 1, 4에서 조건을 만족하는 데이터(사고) 개수 확인
cluster_0_accidents = EPI_middle[(EPI_middle['5-Means'] == 0) & condition_middle]
cluster_1_accidents = EPI_middle[(EPI_middle['5-Means'] == 1) & condition_middle]
cluster_4_accidents = EPI_middle[(EPI_middle['5-Means'] == 4) & condition_middle]

# 결과 출력
print(f'클러스터 0에서 조건을 만족하는 데이터(사고) 개수: {len(cluster_0_accidents)}')
print(f'클러스터 1에서 조건을 만족하는 데이터(사고) 개수: {len(cluster_1_accidents)}')
print(f'클러스터 4에서 조건을 만족하는 데이터(사고) 개수: {len(cluster_4_accidents)}')

# 클러스터 3의 최솟값을 Threshold 로 둘 경우 사고 31개가 추가됨
# Out:
# 클러스터 0에서 조건을 만족하는 데이터(사고) 개수: 14
# 클러스터 1에서 조건을 만족하는 데이터(사고) 개수: 0
# 클러스터 4에서 조건을 만족하는 데이터(사고) 개수: 17

# %%
# 각 클러스터 중심값 출력 (부동소수점 표기법 수정)
클러스터별_중심값_EPI_middle_k5 = pd.DataFrame(scaler_EPI_middle.inverse_transform(kmeans_EPI_middle_k5.cluster_centers_), columns=['수재보험료누적', '수재발생손해액누적'])
# 부동소수점 표기법 수정 및 출력
pd.set_option('display.float_format', lambda x: '{:,.0f}'.format(x))
print("\n각 클러스터 중심값:")
display(클러스터별_중심값_EPI_middle_k5)
# Out:
# 각 클러스터 중심값:
#         수재보험료누적   수재발생손해액누적
# 0 1,396,898,149  12,745,268
# 1 2,307,011,765  19,234,629
# 2 2,075,401,456 951,821,562
# 3 2,200,802,004 360,600,974
# 4 3,080,718,159  21,193,860

# %% [markdown]
# ✅ 1억 9,138만 원

# %% [markdown]
# ### Elbow Method (EPI high)

# %%
# EPI_high에서 '수재보험료누적', '수재발생손해액누적' 열만 선택
df_EPI_high = EPI_high[['수재보험료누적', '수재발생손해액누적']]

# 데이터 표준화
scaler_EPI_high = StandardScaler()
standardized_EPI_high = scaler_EPI_high.fit_transform(df_EPI_high)

# Elbow Method를 사용하여 적절한 클러스터 개수 찾기
sse_EPI_high = []
K_EPI_high = range(1, 11)
for k_high in K_EPI_high:
    kmeans_EPI_high = KMeans(n_clusters=k_high, random_state=42)
    kmeans_EPI_high.fit(standardized_EPI_high)
    sse_EPI_high.append(kmeans_EPI_high.inertia_)

# Elbow Method 그래프 출력
plt.plot(K_EPI_high, sse_EPI_high, color='lightseagreen', marker='o')
plt.xlabel('클러스터 개수')
plt.ylabel('SSE (Sum of Squared Errors)')
plt.title('Elbow Method (EPI high)')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# #### k=7 일 때 k-means (EPI high)

# %%
# K-means 클러스터링 (k=7) - EPI_high 기준
kmeans_EPI_high_k7 = KMeans(n_clusters=7, random_state=42)
clusters_EPI_high_k7 = kmeans_EPI_high_k7.fit_predict(standardized_EPI_high)

# 결과를 데이터프레임에 추가
EPI_high['7-Means'] = clusters_EPI_high_k7

# 클러스터링 결과 시각화
colors_EPI_high_7 = ['darkorange', 'bisque', 'palegreen', 'thistle', 'lightcoral', 'paleturquoise', 'khaki']
for cluster_num_EPI in range(7):
    cluster_data_EPI = EPI_high[clusters_EPI_high_k7 == cluster_num_EPI]
    plt.scatter(cluster_data_EPI['수재보험료누적'],
                cluster_data_EPI['수재발생손해액누적'],
                label=f'클러스터 {cluster_num_EPI}', s=50, color=colors_EPI_high_7[cluster_num_EPI])

# 클러스터 중심 플로팅
cluster_centers_2d_EPI_high_k7 = scaler_EPI_high.inverse_transform(kmeans_EPI_high_k7.cluster_centers_)
plt.scatter(cluster_centers_2d_EPI_high_k7[:, 0], cluster_centers_2d_EPI_high_k7[:, 1],
            color='slategray', marker='X', s=200, label='클러스터 중심')

# 축 레이블 및 그래픽 설정
plt.axhline(y=468789252, color='red', linestyle='--', label='Threshold')
plt.xlabel('수재보험료(단위:백억원)')
plt.ylabel('수재발생손해액(단위:십억원)')
plt.title('7개 군집에 대한 K-means 클러스터링 결과 (EPI high)')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-49-2c2cf0906bfe>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EPI_high['7-Means'] = clusters_EPI_high_k7

# %%
# 7개 클러스터에 해당하는 데이터의 개수 알아내기
count_clusters_EPI_high_k7 = []
for cluster_num in range(7):
    count = len(EPI_high[clusters_EPI_high_k7 == cluster_num])
    count_clusters_EPI_high_k7.append(count)
    print(f'클러스터 {cluster_num}에 해당하는 데이터의 개수: {count}')
# Out:
# 클러스터 0에 해당하는 데이터의 개수: 587
# 클러스터 1에 해당하는 데이터의 개수: 129
# 클러스터 2에 해당하는 데이터의 개수: 323
# 클러스터 3에 해당하는 데이터의 개수: 27
# 클러스터 4에 해당하는 데이터의 개수: 472
# 클러스터 5에 해당하는 데이터의 개수: 148
# 클러스터 6에 해당하는 데이터의 개수: 49

# %%
# 클러스터 6에 해당하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터 찾기
cluster_6_data_min_loss_EPI_high = EPI_high[EPI_high['7-Means'] == 6].nsmallest(1, '수재발생손해액누적')

# 부동소수점 표기법 수정 및 'e' 제거
cluster_6_data_min_loss_EPI_high['수재발생손해액누적'] = cluster_6_data_min_loss_EPI_high['수재발생손해액누적'].apply(lambda x: '{:,.0f}'.format(x))
cluster_6_data_min_loss_EPI_high['수재보험료누적'] = cluster_6_data_min_loss_EPI_high['수재보험료누적'].apply(lambda x: '{:,.0f}'.format(x))
cluster_6_data_min_loss_EPI_high['수재손해율'] = cluster_6_data_min_loss_EPI_high['수재손해율'].apply(lambda x: '{:,.6f}'.format(x))

# 출력
print("\n클러스터6에 속하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터:")
display(cluster_6_data_min_loss_EPI_high)
# Out:
# 클러스터6에 속하는 데이터 중에서 가장 작은 수재발생손해액누적값을 가진 데이터:
#           unique_claim_id            계약번호      UY   종목명        수재보험료누적  \
# 158561  Typhoon HINNAMNOR  C2020032499006  202001  기술보험  6,316,890,950
#
#           수재발생손해액누적     수재손해율  claim횟수  클러스터_3개  7-Means  6-Means
# 158561  468,789,252  0.074212        1        1        6        5

# %%
condition_high = EPI_high['수재발생손해액누적'] > 468789252
condition_high.sum()
# Out:
# 94

# %%
# 클러스터 1, 5에서 조건을 만족하는 데이터(사고) 개수 확인
cluster_1_accidents = EPI_high[(EPI_high['7-Means'] == 1) & condition_high]
cluster_5_accidents = EPI_high[(EPI_high['7-Means'] == 5) & condition_high]

# 결과 출력
print(f'클러스터 1에서 조건을 만족하는 데이터(사고) 개수: {len(cluster_1_accidents)}')
print(f'클러스터 5에서 조건을 만족하는 데이터(사고) 개수: {len(cluster_5_accidents)}')

# 클러스터 6의 최솟값을 Threshold 로 둘 경우 사고 19개가 추가됨
# Out:
# 클러스터 1에서 조건을 만족하는 데이터(사고) 개수: 18
# 클러스터 5에서 조건을 만족하는 데이터(사고) 개수: 1

# %%
# 각 클러스터 중심값 출력 (부동소수점 표기법 수정)
클러스터별_중심값_EPI_high_k7 = pd.DataFrame(scaler_EPI_high.inverse_transform(kmeans_EPI_high_k7.cluster_centers_), columns=['수재보험료누적', '수재발생손해액누적'])
# 부동소수점 표기법 수정 및 출력
pd.set_option('display.float_format', lambda x: '{:,.0f}'.format(x))
print("\n각 클러스터 중심값:")
display(클러스터별_중심값_EPI_high_k7)
# Out:
# 각 클러스터 중심값:
#         수재보험료누적     수재발생손해액누적
# 0 5,022,502,504    34,801,260
# 1 8,992,245,880   300,736,631
# 2 9,382,911,200    31,109,391
# 3 6,925,434,153 1,188,899,709
# 4 6,890,445,207    41,810,084
# 5 5,222,963,822   270,622,174
# 6 5,878,973,160   683,867,620

# %% [markdown]
# ✅ 4억 6,878만 원
